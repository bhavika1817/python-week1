# %% [markdown]
# <h3>qn1

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %% [markdown]
# <h3>qn2

# %%
institue=input("Enter your Institue name:")
# Out:
# Enter your Institue name: HOPE AI

# %% [markdown]
# <h3>qn3

# %%
name=input("Enter your Name:")
age=int(input("Enter your age:"))
sch=input("Enter your school name:")
degree=input("Enter your degree:")
# Out:
# Enter your Name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your degree: B.E CSE

# %% [markdown]
# <h3>qn4

# %%
a=43
b=34
addition=a+b
print('a=',a)
print('b=', b)
print('add=', addition)
# Out:
# a= 43
# b= 34
# add= 77

# %% [markdown]
# <h3>qn5

# %%
a=43
b=34
subtract=a-b
print('a=',a)
print('b=', b)
print('sub=', subtract)
# Out:
# a= 43
# b= 34
# sub= 9

# %% [markdown]
# <h3>qn6

# %%
a=63
b=97
multiply=a*b
print('a=',a)
print('b=', b)
print('mul=', multiply)
# Out:
# a= 63
# b= 97
# mul= 6111

# %% [markdown]
# <h3>qn7

# %%
a=76
b=31
division=a/b
print('a=',a)
print('b=', b)
print('Float div=', division)
# Out:
# a= 76
# b= 31
# Float div= 2.4516129032258065

# %% [markdown]
# <h3>qn8

# %%
a=76
b=31
floor=(a//b)
print('a=',a)
print('b=', b)
print('Floor div=', floor)
# Out:
# a= 76
# b= 31
# Floor div= 2

# %% [markdown]
# <h3>qn9

# %%
a=76
b=31
modulo=(a%b)
print('a=',a)
print('b=', b)
print('modulo=', modulo)
# Out:
# a= 76
# b= 31
# modulo= 14

# %% [markdown]
# <h3>qn10

# %%
a=4
b=4
power=(a**b)
print('a=',a)
print('b=', b)
print('power=', power)
# Out:
# a= 4
# b= 4
# power= 256
